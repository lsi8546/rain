# %% [markdown]
# # 강수_비율_2021년_01월

# %% [markdown]
# ## 라이브러리 임포트

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') 
import seaborn as sns

# %% [markdown]
# ## 한글폰트 확인

# %%
# 한글폰트를 설정합니다.
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

# %%
# 레티나 디스플레이로 폰트가 선명하게 표시되도록 합니다.

from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %% [markdown]
# ## 데이터 로드

# %%
df = pd.read_csv('강수_비율_2021년_01월.csv')
df.head()
# Out:
#   sido_nm sigun_nm  amtprcp  norm_year shortage
# 0   서울특별시    서울특별시     15.3       20.6     5.3
# 1   부산광역시    부산광역시     20.3       32.4    12.1
# 2   부산광역시      기장군     24.4       32.0     7.6
# 3   대구광역시    대구광역시     11.5       21.1     9.6
# 4   대구광역시      달성군     11.4       22.8    11.4

# %%
df.isnull().sum()
# Out:
# sido_nm      0
# sigun_nm     0
# amtprcp      0
# norm_year    0
# shortage     0
# dtype: int64

# %%
df.shape
# Out:
# (167, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
# sido_nm      167 non-null object
# sigun_nm     167 non-null object
# amtprcp      167 non-null float64
# norm_year    167 non-null float64
# shortage     167 non-null object
# dtypes: float64(2), object(3)
# memory usage: 6.6+ KB

# %% [markdown]
# ## 시도별 강수량

# %%
df.groupby("sido_nm").mean().plot.bar(figsize=(12,4), rot=30)
